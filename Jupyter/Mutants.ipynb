# %%
import random
import matplotlib.pyplot as plt
import import_ipynb
import copy
import numpy as np
from Creature_Forest_Base import *
# Out:
# importing Jupyter notebook from Creature_Forest_Base.ipynb

# %%
"""
Mutant behaviour is on a spectrum of chance of playing strategies
"""
starting_population = {
    "Mutant_0": [1]
}
payoff_dict={
    "a":0,
    "b":1,
    "c":0,
    "d":0.1
}
colors = []
simulation_results = run_simulation(ageing_rate=0.01,starting_population=starting_population,
                                    num_generations=2000,gene_step=0.1,mutation_rate=0.01,payoff_dict=payoff_dict)
display_results(simulation_results)
display_results_line(simulation_results)
# Out:
# Final populations:
# Mutant_0 0
# Mutant_0.1 0
# Mutant_0.2 0
# Mutant_0.3 0
# Mutant_0.4 0
# Mutant_0.5 0
# Mutant_0.6 0
# Mutant_0.7 2
# Mutant_0.8 4
# Mutant_0.9 74
# Mutant_1.0 293
# Total: 373

# %%
"""
Mutant behaviour is on a spectrum of chance of playing strategies
"""
starting_population = {
    "Mutant_0": [1]
}
payoff_dict={
    "a":0,
    "b":1,
    "c":0,
    "d":0.1
}
simulation_results = run_simulation(ageing_rate=0.01,starting_population=starting_population,
                                    num_generations=1000,gene_step=0.1,mutation_rate=0.1)
display_results(simulation_results)
display_genes(simulation_results)
# Out:
# Final populations:
# Mutant_0 21
# Mutant_0.1 5
# Mutant_0.2 13
# Mutant_0.3 19
# Mutant_0.4 91
# Mutant_0.5 103
# Mutant_0.6 86
# Mutant_0.7 84
# Mutant_0.8 54
# Mutant_0.9 63
# Mutant_1.0 10
# Total: 549
#     gene  pop
# 0    0.0   21
# 1    0.1    5
# 2    0.2   13
# 3    0.3   19
# 4    0.4   91
# 5    0.5  103
# 6    0.6   86
# 7    0.7   84
# 8    0.8   54
# 9    0.9   63
# 10   1.0   10
