# %%
import random
import matplotlib.pyplot as plt
import import_ipynb
import copy
import numpy as np
from Creature_Forest_Base import *
# Out:
# importing Jupyter notebook from Creature_Forest_Base.ipynb

# %%
"""
Mutant behaviour is on a spectrum of chance of playing strategies
"""
starting_population = {
    "Mutant_0": [1]
}
simulation_results = run_simulation(ageing_rate=0.01,starting_population=starting_population,
                                    num_generations=1000,gene_step=0.5,mutation_rate=0.1)
display_results(simulation_results)
display_genes(simulation_results)
# Out:
# Final populations:
# Mutant_0 160
# Mutant_0.5 252
# Mutant_1.0 195
#
#
# Total: 607
#    gene  pop
# 0   0.0  160
# 1   0.5  252
# 2   1.0  195

# %%
"""
Mutant behaviour is on a spectrum of chance of playing strategies
"""
starting_population = {
    "Mutant_0": [100]
}
simulation_results = run_simulation(ageing_rate=0.01,starting_population=starting_population,
                                    num_generations=1000,gene_step=0.2,mutation_rate=0.1)
display_results(simulation_results)
display_genes(simulation_results)
# Out:
# Final populations:
# Mutant_0 76
# Mutant_0.2 89
# Mutant_0.4 151
# Mutant_0.6 95
# Mutant_0.8 111
# Mutant_1.0 131
#
#
# Total: 653
#    gene  pop
# 0   0.0   76
# 1   0.2   89
# 2   0.4  151
# 3   0.6   95
# 4   0.8  111
# 5   1.0  131
