# %%
import import_ipynb
from Creature_Forest_Base import *
# Out:
# importing Jupyter notebook from Creature_Forest_Base.ipynb

# %%
starting_population = {
    "Dove" : [1],
}
simulation_results = run_simulation(starting_population,ageing_rate=0.01, num_generations=200)
display_results(simulation_results)
# Out:
# Final populations:
# Dove 887
#
#
# Total: 887

# %%
starting_population = {
    "Hawk":[1]
}
colors=['orange']
simulation_results = run_simulation(starting_population,ageing_rate=0.01, num_generations=200)
display_results(simulation_results,colors)
# Out:
# Final populations:
# Hawk 362
#
#
# Total: 362

# %%
starting_population = {
    "Goose":[1]
}
colors=['green']
simulation_results = run_simulation(starting_population,ageing_rate=0.01, num_generations=200)
display_results(simulation_results,colors)
# Out:
# Final populations:
# Goose 856
#
#
# Total: 856

# %%
starting_population = {
    "Crow":[1]
}
colors=['purple']
simulation_results = run_simulation(starting_population,ageing_rate=0.01, num_generations=200)
display_results(simulation_results,colors)
# Out:
# Final populations:
# Crow 879
#
#
# Total: 879
