# %%
import import_ipynb
from Creature_Forest_Base import *
# Out:
# importing Jupyter notebook from Creature_Forest_Base.ipynb

# %%
"""
High amount of variation when all 3 start together on equal footing. Hawks usually eliminate geese and reach usual 
equilibrium with doves. Sometimes geese are able to kill off hawks and equilibriate with doves.
"""

starting_population = {
    "Dove": [1],
    "Hawk": [1],
    "Goose": [1]
}

simulation_results = run_simulation(num_generations=100,starting_population=starting_population,ageing_rate=0.01)
display_results(simulation_results)
# Out:
# Final populations:
# Dove 314
# Hawk 373
# Goose 0
#
#
# Total: 687

# %%
"""
Here the geese aren't able to save the doves from exploitation. Crows get an unfair advantage 
over geese by stealing from doves
"""

starting_population = {
    "Dove": [1],
    "Crow": [1],
    "Goose": [1]
}
colors=['blue','purple','green']
simulation_results = run_simulation(num_generations=100,starting_population=starting_population,ageing_rate=0.01)
display_results(simulation_results,colors)
# Out:
# Final populations:
# Dove 0
# Crow 587
# Goose 305
#
#
# Total: 892

# %%
"""
Hawks and crows reach H/D equilibrium after eliminiating doves
"""

starting_population = {
    "Dove": [1],
    "Hawk": [1],
    "Crow": [1]
}
colors=['blue','orange','purple']
simulation_results = run_simulation(num_generations=100,starting_population=starting_population,ageing_rate=0.01)
display_results(simulation_results,colors)
# Out:
# Final populations:
# Dove 0
# Hawk 327
# Crow 355
#
#
# Total: 682

# %%
"""
Crows gain early advantage over hawks due to geese killing off hawks early on. 
Once geese are eliminated, H/D equilibrium is reached
"""

starting_population = {
    "Hawk": [1],
    "Crow": [1],
    "Goose": [1]
}
colors=['orange','purple','green']
simulation_results = run_simulation(num_generations=100,starting_population=starting_population,ageing_rate=0.01)
display_results(simulation_results,colors)
# Out:
# Final populations:
# Hawk 342
# Crow 350
# Goose 0
#
#
# Total: 692

# %%
"""
Geese and doves can't save each other; pressure from Hawks and Crows is too much. 
H/D equilibrium reached
"""

starting_population = {
    "Dove": [1],
    "Hawk": [1],
    "Crow": [1],
    "Goose": [1]
}
colors=['blue','orange','purple','green']
simulation_results = run_simulation(num_generations=100,starting_population=starting_population,ageing_rate=0.01)
display_results(simulation_results,colors)
# Out:
# Final populations:
# Dove 0
# Hawk 338
# Crow 315
# Goose 0
#
#
# Total: 653
