# %%
import import_ipynb
from Creature_Forest_Base import *
# Out:
# importing Jupyter notebook from Creature_Forest_Base.ipynb

# %%
starting_population = {
    "Dove": [1],
    "Hawk": [1],
}
simulation_results = run_simulation(starting_population,ageing_rate=0.01)
display_results(simulation_results)
# Out:
# Final populations:
# Dove 340
# Hawk 350
#
#
# Total: 690

# %%
starting_population = {
    "Dove": [1],
    "Goose": [1],
}
colors = ['blue','green']
simulation_results = run_simulation(starting_population,ageing_rate=0.01)
display_results(simulation_results,colors)
# Out:
# Final populations:
# Dove 406
# Goose 466
#
#
# Total: 872

# %%
starting_population = {
    "Dove": [1],
    "Crow": [1],
}
colors = ['blue','purple']
simulation_results = run_simulation(starting_population,ageing_rate=0.01)
display_results(simulation_results,colors)
# Out:
# Final populations:
# Dove 0
# Crow 882
#
#
# Total: 882

# %%
starting_population = {
    "Hawk": [1],
    "Crow": [1],
}
colors = ['orange','purple']
simulation_results = run_simulation(starting_population,ageing_rate=0.01)
display_results(simulation_results,colors)
# Out:
# Final populations:
# Hawk 350
# Crow 269
#
#
# Total: 619

# %%
starting_population = {
    "Hawk": [1],
    "Goose": [1],
}
colors = ['orange','green']
simulation_results = run_simulation(starting_population,ageing_rate=0.01)
display_results(simulation_results,colors)
# Out:
# Final populations:
# Hawk 0
# Goose 881
#
#
# Total: 881

# %%
starting_population = {
    "Crow": [1],
    "Goose": [1],
}
colors = ['purple','green']
simulation_results = run_simulation(starting_population,ageing_rate=0.01)
display_results(simulation_results,colors)
# Out:
# Final populations:
# Crow 452
# Goose 437
#
#
# Total: 889
